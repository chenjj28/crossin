# %% [markdown]
# ## 利用 Pyecharts 将链家房源信息、A 股基本信息根据相应特点制作地图图表
# ### 1.根据任务 4 所统计的上海各个区的房均价数据，利用 Pyecharts 中的 Map，以上海地图为背景作可视化展示图
# 提示:可以直接定义 districts = ['金山区', '奉贤区', '嘉定区', '松江区', '青浦区', '宝山区', '闵行区 ', '浦东新区', '普陀区', '杨浦区', '虹口区', '长宁区', '静安区', '徐汇区', '黄浦区']

# %%
from pyecharts.charts import Map,Geo
from pyecharts import options as opts
import pandas as pd
df = pd.read_csv('Task_4_lianjia_sale.csv')
df_avg = df.groupby(['区域'])['价格'].agg(区域平均价格='mean').sort_values(by='区域平均价格')
df_avg
# Out:
#           区域平均价格
# 区域
# 金山  19304.818824
# 奉贤  23662.131268
# 松江  36461.715479
# 嘉定  36587.687199
# 青浦  37078.860149
# 宝山  42577.796632
# 闵行  49080.587398
# 浦东  55413.057914
# 普陀  57943.126871
# 杨浦  62726.673854
# 虹口  66165.352834
# 长宁  72099.617088
# 静安  74304.768542
# 徐汇  75395.941983
# 黄浦  95015.086252

# %%
districts = [i+'区' if i != '浦东' else i+'新区' for i in df_avg.index.values]
price = df_avg['区域平均价格'].values.tolist()
map = (Map()
      .add("元/每平方米", [list(z) for z in zip(districts,price)],maptype='上海')
      .set_global_opts(
          title_opts=opts.TitleOpts(title='上海各区平均价格'),
          visualmap_opts=opts.VisualMapOpts(max_=100000, min_=10000))
      )
map.render_notebook()
# Out:
# /Users/jiejingchen/opt/anaconda3/lib/python3.7/site-packages/pyecharts-1.8.1-py3.7.egg/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '上海':'https://assets.pyecharts.org/assets/maps/shanghai'
#         }
#     });
# </script>
#
#         <div id="6393985d1be443539dab2a7746c72a0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '上海'], function(echarts) {
#                 var chart_6393985d1be443539dab2a7746c72a0f = echarts.init(
#                     document.getElementById('6393985d1be443539dab2a7746c72a0f'), 'white', {renderer: 'canvas'});
#                 var option_6393985d1be443539dab2a7746c72a0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
# ...

# %% [markdown]
# ### 2.导入 tushare 数据包，提取 A 股基本数据信息，利用 groupby 函数统计每个省份的公司数量，并以中国地图为背景作相应图表

# %%
import tushare as ts
df1 = ts.get_area_classified()
df2 = df1.groupby(['area'])['name'].agg(公司数量='count')
df2
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://tushare.pro/document/2
#       公司数量
# area
# 上海     308
# 云南      36
# 内蒙      25
# 北京     356
# 吉林      43
# 四川     132
# 天津      57
# 宁夏      14
# 安徽     112
# 山东     214
# 山西      37
# 广东     330
# 广西      38
# 新疆      55
# 江苏     443
# 江西      45
# 河北      58
# 河南      82
# 浙江     473
# 海南      31
# 深圳     311
# 湖北     109
# 湖南     113
# 甘肃      33
# 福建     140
# 西藏      19
# 贵州      30
# 辽宁      74
# 重庆      54
# 陕西      55
# 青海      12
# 黑龙江     38

# %%
province = df2.index.values.tolist()
province[province.index('内蒙')] = '内蒙古'
number = df2['公司数量'].values.tolist()
map_china = (Map()
            .add("公司数量", [list(x) for x in zip(province,number)],maptype='china')
            .set_global_opts(
            title_opts=opts.TitleOpts(title='A股上市公司分布'),
            visualmap_opts=opts.VisualMapOpts(max_=500, min_=10))
            )
map_china.render_notebook()
# Out:
# /Users/jiejingchen/opt/anaconda3/lib/python3.7/site-packages/pyecharts-1.8.1-py3.7.egg/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="2d2cc0bbaa6a4e37afe820cbfc6467b0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_2d2cc0bbaa6a4e37afe820cbfc6467b0 = echarts.init(
#                     document.getElementById('2d2cc0bbaa6a4e37afe820cbfc6467b0'), 'white', {renderer: 'canvas'});
#                 var option_2d2cc0bbaa6a4e37afe820cbfc6467b0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
# ...
